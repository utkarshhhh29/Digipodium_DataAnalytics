# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt #basic graphs
import seaborn as sns #advanced graphs
import plotly.express as px #interactive graphs

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # Categorical Data
#
# - columns that have text are generally categorical
# - the first step is to count the number of unique values in column
# - then plot the count of each category
# - following charts are a good way to visualize categorical data
#     - bar chart
#     - pie chart
#     - donut chart
#     - line chart
#     - area chart

# %%
print(titanic['survived'].unique()) #to check if the column is ccategorical or not
print(titanic['pclass'].unique())
# Out:
# [0 1]
# [3 1 2]

# %%
survival_count = titanic['survived'].value_counts()
survival_count.plot(kind='pie',autopct='%.1f%%', title='Survival Rates') #autopct = auto percentage
plt.show()

# %%
floors = titanic['pclass'].value_counts()
floors
# Out:
# 3    491
# 1    216
# 2    184
# Name: pclass, dtype: int64

# %%
survival_count.plot(
    kind='pie',
    autopct='%.1f%%',
    title='Survival Rate',
    labels=['Survived','Not Survived'],
    colors=['#66b3ff','#ff9999'],
    labeldistance=1.1,
    wedgeprops={'width':0.5}
    )
plt.show()

# %%
floors = titanic['pclass'].value_counts()
floors.plot(kind='pie',autopct='%.1f%%', title='Floors')
plt.show()

# %%
floors.plot(
    kind='pie',
    autopct='%.1f%%',
    title='Floors',
    labels=['1st floor','2nd floor','3rd floor'],
    colors=['#66b3ff','#ff9999','orange'],
    labeldistance=1.1,
    wedgeprops={'width':0.7}
    )
plt.show()

# %%
gender = titanic['sex'].value_counts()
gender.plot(kind='pie',autopct='%.1f%%', title='Sex')
plt.show()

# %%
gender.plot(
    kind='pie',
    autopct='%.1f%%',
    title='Sex',
    labels=['Male','Female'],
    colors=['Brown','Pink'],
    labeldistance=1.1,
    wedgeprops={'width':0.7}
    )
plt.show()

# %%
clas = titanic['class'].value_counts()
clas.plot(kind='pie',autopct='%.1f%%', title='Class')
plt.show()

# %%
clas.plot(
    kind='pie',
    autopct='%.1f%%',
    title='Class',
    labels=['First','Second','Third'],
    colors=['Yellow','Blue','green'],
    labeldistance=1.1,
    wedgeprops={'width':0.7}
    )
plt.show()

# %% [markdown]
# # Seaborn
# -for complete data visualization using simple code

# %%
sns.countplot(data=titanic, x='alive')
# Out:
# <Axes: xlabel='alive', ylabel='count'>

# %%
sns.countplot(data=titanic, x='alive',hue='sex') #hue is used for dviding category
# Out:
# <Axes: xlabel='alive', ylabel='count'>

# %%
sns.countplot(data=titanic, x='alive',hue='pclass')
# Out:
# <Axes: xlabel='alive', ylabel='count'>

# %%
sns.countplot(data=titanic, x='pclass',hue='alive')
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
sns.countplot(data=titanic, y='alive',hue='embark_town')
# Out:
# <Axes: xlabel='count', ylabel='alive'>

# %%
sns.jointplot(data=titanic,x='age',y='fare')

# %%
sns.jointplot(data=titanic,x='age',y='fare',kind='kde',color='green')

# %%
sns.jointplot(data=titanic,x='age',y='fare',kind='hist',color='red')

# %%
sns.jointplot(data=titanic,x='age',y='fare',kind='scatter',color='green',hue='alive')
